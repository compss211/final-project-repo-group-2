# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
item_info = pd.read_csv('../data/meta_data.csv')
review_data = pd.read_csv('../data/raw_review_data.csv')

# %%
review_data['timestamp'] = pd.to_datetime(review_data['timestamp'], unit='ms')
review_data_20_25 = review_data[(review_data['timestamp'].dt.year >= 2020) & (review_data['timestamp'].dt.year <= 2025)]

# %%
review_data.shape
# Out:
# (2500939, 10)

# %%
review_data_20_25.shape
# Out:
# (831935, 10)

# %%
joined_df = pd.merge(review_data_20_25, item_info, on='parent_asin', how='left')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 joined_df = pd.merge(review_data_20_25, item_info, on='parent_asin', how='left')
#
# File /opt/miniconda3/envs/compss211/lib/python3.11/site-packages/pandas/core/reshape/merge.py:170, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     155     return _cross_merge(
#     156         left_df,
#     157         right_df,
#    (...)    167         copy=copy,
#     168     )
#     169 else:
# --> 170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#     173         how=how,
#     174         on=on,
#     175         left_on=left_on,
#     176         right_on=right_on,
#     177         left_index=left_index,
#     178         right_index=right_index,
#     179         sort=sort,
# ...

# %%
joined_df.shape
# Out:
# (831935, 23)

# %%
joined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 831935 entries, 0 to 831934
# Data columns (total 23 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   rating             831935 non-null  float64
#  1   title_x            831679 non-null  object
#  2   text               831661 non-null  object
#  3   images_x           831935 non-null  object
#  4   asin               831935 non-null  object
#  5   parent_asin        831935 non-null  object
#  6   user_id            831935 non-null  object
#  7   timestamp          831935 non-null  datetime64[ns]
#  8   helpful_vote       831935 non-null  int64
#  9   verified_purchase  831935 non-null  bool
#  10  main_category      831935 non-null  object
#  11  title_y            831888 non-null  object
#  12  average_rating     831935 non-null  float64
#  13  rating_number      831935 non-null  int64
#  14  features           831935 non-null  object
# ...

# %%
joined_df['bought_together'].isnull().sum()
# Out:
# np.int64(831935)

# %%
joined_df = joined_df.drop(columns=['bought_together'])

# %%
joined_df.to_csv('../data/joined_data.csv', index=False)
